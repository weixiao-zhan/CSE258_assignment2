# %%
import torch
best_b_model = torch.load("best_b_model.ckpt")
best_l_model = torch.load("best_l_model.ckpt")
best_tb_model = torch.load("best_tb_model.ckpt")
best_tl_model = torch.load("best_tl_model.ckpt")

# %%
from matplotlib import pyplot as plt


plt.scatter(396811, 0.14765022922054435, 
            label="bias", marker='^', s=100, c='green')
plt.scatter(793621, 0.1472210347657351, 
            label="latent factor", marker='^', s=100, c='orange')

plt.scatter(1891560, 0.1264476679243775, 
            label="temporal bias", marker='s', s=100, c='green')
plt.scatter(2288370, 0.12616110692055538, 
            label="temporal latent factor", marker='s', s=100, c='orange')

plt.scatter(3971443, 0.16804393868770545,
            label='word2vec MLP', s=100)

plt.scatter(3975348, 0.15264586113890483,
            label='tfidf MLP', s=100, c='pink')


# Add labels and legend
plt.xlabel('model size')
plt.ylabel('test loss')
plt.title('regression performance with respect to model size')
plt.legend()
plt.show()
